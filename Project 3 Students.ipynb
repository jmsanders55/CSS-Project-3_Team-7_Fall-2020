# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import cross_val_score, GridSearchCV, train_test_split
from sklearn.linear_model import LogisticRegression
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore')
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
import seaborn as sns

# Make sure to import other libraries that will be necessary for training models!

# %%
# Inspections Data 2011 - 2013
chicago_inspections_2011_to_2013 = pd.read_csv("Chicago Inspections 2011-2013.csv")

# Inspections Data 2014
chicago_inspections_2014 = pd.read_csv("Chicago Inspections 2014.csv")

# %%
# Look at the inspections data
chicago_inspections_2011_to_2013.head()
# Out:
#    Inspection_ID Inspection_Date                      DBA_Name  \
# 0         269961      2013-01-31                    SEVEN STAR
# 1         507211      2011-10-18                  PANERA BREAD
# 2         507212      2011-10-18      LITTLE QUIAPO RESTAURANT
# 3         507216      2011-10-19  SERGIO'S TAQUERIA PIZZA INC.
# 4         507219      2011-10-20         TARGET STORE # T-2079
#
#                    AKA_Name  License  Facility_Type             Risk  \
# 0                SEVEN STAR    30790  Grocery Store     Risk 3 (Low)
# 1              PANERA BREAD  1475890     Restaurant    Risk 1 (High)
# 2  LITTLE QUIAPO RESTAURANT  1740130     Restaurant    Risk 1 (High)
# 3   SERGIO'S TAQUERIA PIZZA  1447363     Restaurant    Risk 1 (High)
# 4                    TARGET  1679459     Restaurant  Risk 2 (Medium)
#
#                  Address     City State      Zip Inspection_Type Results  \
# 0       3352 N BROADWAY   CHICAGO    IL  60657.0         Canvass    Pass
# 1    6059 N LINCOLN AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 2   6259 N MCCORMICK RD   CHICAGO    IL  60659.0         Canvass    Fail
# 3  3253 W BRYN MAWR AVE   CHICAGO    IL  60659.0         Canvass    Pass
# 4   2112 W PETERSON AVE   CHICAGO    IL  60659.0         Canvass    Fail
#
#     Latitude  Longitude                                  Location  \
# 0  41.943359 -87.644999  (41.943359344775146, -87.64499875300952)
# 1  41.991919 -87.709631   (41.99191947239194, -87.70963133440333)
# 2  41.995632 -87.712707   (41.99563177556418, -87.71270678169132)
# 3  41.982933 -87.710982  (41.982933189164974, -87.71098225381141)
# 4  41.990729 -87.682979   (41.99072921796059, -87.68297945359863)
#
#   Facility_Type_Clean  criticalCount  seriousCount  minorCount  pass_flag  \
# 0               Other              0             0           2          1
# 1          Restaurant              0             0           3          1
# 2          Restaurant              0             2           6          0
# 3          Restaurant              0             0           6          1
# 4          Restaurant              0             2           6          0
#
#    fail_flag  pastFail  pastCritical  pastSerious  pastMinor  timeSinceLast  \
# 0          0         0             0            0          0            2.0
# 1          0         0             0            0          0            2.0
# 2          1         0             0            0          0            2.0
# 3          0         0             0            0          0            2.0
# 4          1         0             0            0          0            2.0
#
#    firstRecord                ID  LICENSE_ID  ACCOUNT_NUMBER  \
# 0            1    30790-20110416   2081412.0         63759.0
# 1            1  1475890-20110416   2081695.0        207283.0
# 2            1  1740130-20110216   2070145.0          3107.0
# 3            1  1447363-20110216   2071895.0        270993.0
# 4            1  1679459-20100216   2009972.0         15538.0
#
#                      LEGAL_NAME        DOING_BUSINESS_AS_NAME  \
# 0            VIRGINIA DELA ROSA                    SEVEN STAR
# 1                   PANERA, LLC                  PANERA BREAD
# 2                ENELITA GARCIA      LITTLE QUIAPO RESTAURANT
# 3  SERGIO'S TAZUERIA PIZZA INC.  SERGIO'S TAQUERIA PIZZA INC.
# 4            TARGET CORPORATION         TARGET STORE # T-2079
#
#                  ADDRESS     CITY STATE  ZIP_CODE  WARD  PRECINCT  \
# 0    3352 N BROADWAY   1  CHICAGO    IL   60657.0  44.0      33.0
# 1  6059 N LINCOLN AVE  C  CHICAGO    IL   60659.0  50.0      23.0
# 2    6259 N MCCORMICK RD  CHICAGO    IL   60659.0  50.0      25.0
# 3   3253 W BRYN MAWR AVE  CHICAGO    IL   60659.0  39.0      48.0
# 4    2112 W PETERSON AVE  CHICAGO    IL   60659.0  40.0      18.0
#
#   WARD_PRECINCT  POLICE_DISTRICT  LICENSE_CODE        LICENSE_DESCRIPTION  \
# 0         44-33             19.0        1006.0  Retail Food Establishment
# 1         50-23             24.0        1006.0  Retail Food Establishment
# 2         50-25             17.0        1006.0  Retail Food Establishment
# 3         39-48             17.0        1006.0  Retail Food Establishment
# 4         40-18             24.0        1006.0  Retail Food Establishment
#
#   BUSINESS_ACTIVITY_ID                 BUSINESS_ACTIVITY  LICENSE_NUMBER  \
# 0                  775  Retail Sales of Perishable Foods         30790.0
# 1                  775  Retail Sales of Perishable Foods       1475890.0
# 2                  775  Retail Sales of Perishable Foods       1740130.0
# 3                  775  Retail Sales of Perishable Foods       1447363.0
# 4                  775  Retail Sales of Perishable Foods       1679459.0
#
#   APPLICATION_TYPE LICENSE_TERM_START_DATE LICENSE_TERM_EXPIRATION_DATE  \
# 0            RENEW              2011-04-16                   2013-04-15
# 1            RENEW              2011-04-16                   2013-04-15
# 2            RENEW              2011-02-16                   2013-02-15
# 3            RENEW              2011-02-16                   2013-02-15
# 4            RENEW              2010-02-16                   2012-02-15
#
#   LICENSE_STATUS   LATITUDE  LONGITUDE     minDate     maxDate  \
# 0            AAI  41.943359 -87.644999  2002-02-16  2015-04-15
# 1            AAI  41.991919 -87.709631  2004-05-05  2019-04-15
# 2            AAI  41.995632 -87.712707  2007-03-22  2017-02-15
# 3            AAI  41.982933 -87.710982  2003-12-31  2019-02-15
# 4            AAI  41.990729 -87.682979  2006-07-07  2018-02-15
#
#    ageAtInspection  consumption_on_premises_incidental_activity  tobacco  \
# 0        10.964384                                            0        1
# 1         7.457534                                            0        0
# 2         4.578082                                            0        0
# 3         7.805479                                            0        0
# 4         5.290411                                            0        0
#
#    package_goods  outdoor_patio  public_place_of_amusement  \
# 0              0              0                          0
# 1              0              0                          0
# 2              0              0                          0
# 3              0              0                          0
# 4              1              0                          0
#
#    limited_business_license  childrens_services_facility_license  tavern  \
# 0                         1                                    0       0
# 1                         0                                    0       0
# 2                         0                                    0       0
# 3                         0                                    0       0
# 4                         1                                    0       0
#
#    regulated_business_license  filling_station  caterers_liquor_license  \
# 0                           0                0                        0
# 1                           0                0                        0
# 2                           0                0                        0
# 3                           0                0                        0
# 4                           0                0                        0
#
#    mobile_food_license  precipIntensity  temperatureMax  windSpeed  humidity  \
# 0                    0         0.014587       53.496667  13.340000  0.900000
# 1                    0         0.001907       59.046667  13.016667  0.550000
# 2                    0         0.001907       59.046667  13.016667  0.550000
# 3                    0         0.002737       56.153333  10.863333  0.616667
# 4                    0         0.009987       52.730000  16.266667  0.690000
#
#    heat_burglary  heat_garbage  heat_sanitation  criticalFound
# 0      26.992376     12.768572        37.748787              0
# 1      13.976557     12.895485        15.412267              0
# 2      12.611239      8.004220         8.320330              0
# 3      35.906383     26.238645        38.186618              0
# 4       9.530785      3.401567         2.126788              0

# %%
# List column names
chicago_inspections_2011_to_2013.columns
# Out:
# Index(['Inspection_ID', 'Inspection_Date', 'DBA_Name', 'AKA_Name', 'License',
#        'Facility_Type', 'Risk', 'Address', 'City', 'State', 'Zip',
#        'Inspection_Type', 'Results', 'Latitude', 'Longitude', 'Location',
#        'Facility_Type_Clean', 'criticalCount', 'seriousCount', 'minorCount',
#        'pass_flag', 'fail_flag', 'pastFail', 'pastCritical', 'pastSerious',
#        'pastMinor', 'timeSinceLast', 'firstRecord', 'ID', 'LICENSE_ID',
#        'ACCOUNT_NUMBER', 'LEGAL_NAME', 'DOING_BUSINESS_AS_NAME', 'ADDRESS',
#        'CITY', 'STATE', 'ZIP_CODE', 'WARD', 'PRECINCT', 'WARD_PRECINCT',
#        'POLICE_DISTRICT', 'LICENSE_CODE', 'LICENSE_DESCRIPTION',
#        'BUSINESS_ACTIVITY_ID', 'BUSINESS_ACTIVITY', 'LICENSE_NUMBER',
#        'APPLICATION_TYPE', 'LICENSE_TERM_START_DATE',
#        'LICENSE_TERM_EXPIRATION_DATE', 'LICENSE_STATUS', 'LATITUDE',
#        'LONGITUDE', 'minDate', 'maxDate', 'ageAtInspection',
#        'consumption_on_premises_incidental_activity', 'tobacco',
#        'package_goods', 'outdoor_patio', 'public_place_of_amusement',
#        'limited_business_license', 'childrens_services_facility_license',
#        'tavern', 'regulated_business_license', 'filling_station',
#        'caterers_liquor_license', 'mobile_food_license', 'precipIntensity',
#        'temperatureMax', 'windSpeed', 'humidity', 'heat_burglary',
#        'heat_garbage', 'heat_sanitation', 'criticalFound'],
#       dtype='object')

# %%
# Drop column names related to geography, identification, and pass/fail flags that perfectly predict the outcome
chicago_inspections_2011_to_2013.drop(columns = ['AKA_Name', 
                                                 'License',
                                                'Address',
                                                'City',
                                                'State',
                                                'Zip',
                                                'Latitude',
                                                'Longitude',
                                                'Location',
                                                'ID',
                                                'LICENSE_ID',
                                                 'LICENSE_TERM_START_DATE',
                                                 'LICENSE_TERM_EXPIRATION_DATE',
                                                 'LICENSE_STATUS',
                                                'ACCOUNT_NUMBER',
                                                'LEGAL_NAME',
                                                'DOING_BUSINESS_AS_NAME',
                                                'ADDRESS',
                                                'CITY',
                                                'STATE',
                                                'ZIP_CODE',
                                                'WARD',
                                                'PRECINCT',
                                                'LICENSE_CODE',
                                                'BUSINESS_ACTIVITY_ID',
                                                'BUSINESS_ACTIVITY',
                                                'LICENSE_NUMBER',
                                                'LATITUDE',
                                                'LONGITUDE',
                                                'pass_flag',
                                                'fail_flag'],
                                     inplace = True)

chicago_inspections_2011_to_2013.set_index(['Inspection_ID', 'DBA_Name'], inplace = True)

# %%
# Convert the Inspection Date to a datetime format
chicago_inspections_2011_to_2013['Inspection_Date'] = pd.to_datetime(chicago_inspections_2011_to_2013['Inspection_Date'], infer_datetime_format=True)

# %% [markdown]
# ## Visualization

# %% [markdown]
# What do inspections look like over time?

# %%
# Visualize Inspections Over Time
chicago_inspections_2011_to_2013['Inspection_MonthYear'] = chicago_inspections_2011_to_2013['Inspection_Date'].dt.to_period('M')
counts_by_day = chicago_inspections_2011_to_2013.groupby('Inspection_MonthYear').count().rename(columns = {'Facility_Type': 'Count'})['Count'].reset_index()
counts_by_day.set_index(["Inspection_MonthYear"], inplace = True)
counts_by_day.plot(title = "Inspections by Month and Year")

# %% [markdown]
# What do the results look like?

# %%
# Inspection Results
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "Results",
           kind = "count")

plt.title("Inspection Results")
plt.show()

# %% [markdown]
# What if we separate by facility type?

# %%
# Inspection Results by Facility Type (Restaurant or Not)
sns.catplot(data = chicago_inspections_2011_to_2013,
           x = "Results",
           kind = "count",
           hue = 'Facility_Type_Clean')

plt.title("Inspection Results by Facility Type")
plt.show()

# %% [markdown]
# ## Preprocess Data

# %%
# Drop datetime info
chicago_inspections_2011_to_2013 = chicago_inspections_2011_to_2013.dropna().drop(['Inspection_Date',
                                      'minDate',
                                      'maxDate',
                                      'Inspection_MonthYear'],
                                      axis = 1)

# %%
# Set target variable. 
y = chicago_inspections_2011_to_2013['Results']
## Comment out the following code if you don't want to binarize the target variable
y = y.replace({'Pass w/ Conditions': 'Pass'})
lb_style = LabelBinarizer()
y = lb_style.fit_transform(y)
# Recode 0s and 1s so 1s are "Fail"
y = np.where(y == 1, 0 ,1)

# All other features in X
X = chicago_inspections_2011_to_2013.drop(columns = ['Results'])
X = pd.get_dummies(X)

# %%
X.head()
# Out:
# nspection_ID DBA_Name
# 269961        SEVEN STAR                                                0
# 507211        PANERA BREAD                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                              0
# 507219        TARGET STORE # T-2079                                     0
#
#                                             LICENSE_DESCRIPTION_Limited Business License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                               0
# 507211        PANERA BREAD                                                             0
# 507212        LITTLE QUIAPO RESTAURANT                                                 0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                             0
# 507219        TARGET STORE # T-2079                                                    0
#
#                                             LICENSE_DESCRIPTION_Long-Term Care Facility  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             LICENSE_DESCRIPTION_Manufacturing Establishments  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                   0
# 507211        PANERA BREAD                                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                 0
# 507219        TARGET STORE # T-2079                                                        0
#
#                                             LICENSE_DESCRIPTION_Mobile Food License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             LICENSE_DESCRIPTION_Motor Vehicle Repair : Engine Only (Class II)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Motor Vehicle Repair: Engine/Body(Class III)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Music and Dance  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                      0
# 507211        PANERA BREAD                                                    0
# 507212        LITTLE QUIAPO RESTAURANT                                        0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                    0
# 507219        TARGET STORE # T-2079                                           0
#
#                                             LICENSE_DESCRIPTION_Navy Pier Kiosk License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             LICENSE_DESCRIPTION_Navy Pier Vendor (Food)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                              0
# 507211        PANERA BREAD                                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                            0
# 507219        TARGET STORE # T-2079                                                   0
#
#                                             LICENSE_DESCRIPTION_Not-For-Profit Club  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             LICENSE_DESCRIPTION_Outdoor Patio  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Package Goods  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Public Garage  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             LICENSE_DESCRIPTION_Public Place of Amusement  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                0
# 507211        PANERA BREAD                                                              0
# 507212        LITTLE QUIAPO RESTAURANT                                                  0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              0
# 507219        TARGET STORE # T-2079                                                     0
#
#                                             LICENSE_DESCRIPTION_Regulated Business License  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                 0
# 507211        PANERA BREAD                                                               0
# 507212        LITTLE QUIAPO RESTAURANT                                                   0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                               0
# 507219        TARGET STORE # T-2079                                                      0
#
#                                             LICENSE_DESCRIPTION_Residential Real Estate Developer  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food - Seasonal Lakefront Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food Est.-Supplemental License for Dog-Friendly Areas  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Retail Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                1
# 507211        PANERA BREAD                                                              1
# 507212        LITTLE QUIAPO RESTAURANT                                                  1
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                              1
# 507219        TARGET STORE # T-2079                                                     1
#
#                                             LICENSE_DESCRIPTION_Scavenger, Private  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             LICENSE_DESCRIPTION_Shared Kitchen User  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                          0
# 507211        PANERA BREAD                                                        0
# 507212        LITTLE QUIAPO RESTAURANT                                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                        0
# 507219        TARGET STORE # T-2079                                               0
#
#                                             LICENSE_DESCRIPTION_Special Event Food  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                         0
# 507211        PANERA BREAD                                                       0
# 507212        LITTLE QUIAPO RESTAURANT                                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                       0
# 507219        TARGET STORE # T-2079                                              0
#
#                                             LICENSE_DESCRIPTION_Tavern  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                             0
# 507211        PANERA BREAD                                           0
# 507212        LITTLE QUIAPO RESTAURANT                               0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                           0
# 507219        TARGET STORE # T-2079                                  0
#
#                                             LICENSE_DESCRIPTION_Tire Facilty Class I (100 - 1,000 Tires)  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                    0
# 507211        PANERA BREAD                                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                  0
# 507219        TARGET STORE # T-2079                                                         0
#
#                                             LICENSE_DESCRIPTION_Tobacco  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                              0
# 507211        PANERA BREAD                                            0
# 507212        LITTLE QUIAPO RESTAURANT                                0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                            0
# 507219        TARGET STORE # T-2079                                   0
#
#                                             LICENSE_DESCRIPTION_Wholesale Food Establishment  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                                   0
# 507211        PANERA BREAD                                                                 0
# 507212        LITTLE QUIAPO RESTAURANT                                                     0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                                 0
# 507219        TARGET STORE # T-2079                                                        0
#
#                                             LICENSE_DESCRIPTION_Wrigley Field  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                                    0
# 507211        PANERA BREAD                                                  0
# 507212        LITTLE QUIAPO RESTAURANT                                      0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                                  0
# 507219        TARGET STORE # T-2079                                         0
#
#                                             APPLICATION_TYPE_C_EXPA  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                          0
# 507211        PANERA BREAD                                        0
# 507212        LITTLE QUIAPO RESTAURANT                            0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                        0
# 507219        TARGET STORE # T-2079                               0
#
#                                             APPLICATION_TYPE_C_LOC  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         0
# 507211        PANERA BREAD                                       0
# 507212        LITTLE QUIAPO RESTAURANT                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       0
# 507219        TARGET STORE # T-2079                              0
#
#                                             APPLICATION_TYPE_ISSUE  \
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         0
# 507211        PANERA BREAD                                       0
# 507212        LITTLE QUIAPO RESTAURANT                           0
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       0
# 507219        TARGET STORE # T-2079                              0
#
#                                             APPLICATION_TYPE_RENEW
# Inspection_ID DBA_Name
# 269961        SEVEN STAR                                         1
# 507211        PANERA BREAD                                       1
# 507212        LITTLE QUIAPO RESTAURANT                           1
# 507216        SERGIO'S TAQUERIA PIZZA INC.                       1
# 507219        TARGET STORE # T-2079                              1

# %% [markdown]
# ## Feature Selection:
# TBD

# %%
X.cov(min_periods=1) #min number of observation per column to get results
# Out:
# 320657e-05
# APPLICATION_TYPE_RENEW                                        3.416216e-05
#
#                                    LICENSE_DESCRIPTION_Outdoor Patio  \
# criticalCount                                          -2.549364e-05
# seriousCount                                            1.856992e-05
# minorCount                                              2.305562e-04
# pastFail                                                5.576094e-05
# pastCritical                                           -9.589977e-06
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                      -2.133002e-07
# APPLICATION_TYPE_C_EXPA                                -1.706402e-07
# APPLICATION_TYPE_C_LOC                                 -3.071523e-07
# APPLICATION_TYPE_ISSUE                                 -1.660329e-05
# APPLICATION_TYPE_RENEW                                  1.708108e-05
#
#                                    LICENSE_DESCRIPTION_Package Goods  \
# criticalCount                                              -0.000072
# seriousCount                                                0.000815
# minorCount                                                 -0.000486
# pastFail                                                    0.000096
# pastCritical                                               -0.000035
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                          -0.000002
# APPLICATION_TYPE_C_EXPA                                    -0.000002
# APPLICATION_TYPE_C_LOC                                     -0.000003
# APPLICATION_TYPE_ISSUE                                     -0.000174
# APPLICATION_TYPE_RENEW                                      0.000179
#
#                                    LICENSE_DESCRIPTION_Public Garage  \
# criticalCount                                          -5.098728e-05
# seriousCount                                            1.024566e-04
# minorCount                                              3.894862e-06
# pastFail                                                1.115219e-04
# pastCritical                                           -1.917995e-05
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                      -4.266004e-07
# APPLICATION_TYPE_C_EXPA                                -3.412803e-07
# APPLICATION_TYPE_C_LOC                                 -6.143046e-07
# APPLICATION_TYPE_ISSUE                                 -3.320657e-05
# APPLICATION_TYPE_RENEW                                  3.416216e-05
#
#                                    LICENSE_DESCRIPTION_Public Place of Amusement  \
# criticalCount                                                      -3.824046e-05
# seriousCount                                                       -7.012031e-05
# minorCount                                                          1.172255e-04
# pastFail                                                           -1.433377e-05
# pastCritical                                                       -1.438497e-05
# ...                                                                          ...
# LICENSE_DESCRIPTION_Wrigley Field                                  -3.199503e-07
# APPLICATION_TYPE_C_EXPA                                            -2.559602e-07
# APPLICATION_TYPE_C_LOC                                             -4.607284e-07
# APPLICATION_TYPE_ISSUE                                             -2.490493e-05
# APPLICATION_TYPE_RENEW                                              2.562162e-05
#
#                                    LICENSE_DESCRIPTION_Regulated Business License  \
# criticalCount                                                            0.000057
# seriousCount                                                            -0.000178
# minorCount                                                              -0.001225
# pastFail                                                                -0.000076
# pastCritical                                                            -0.000077
# ...                                                                           ...
# LICENSE_DESCRIPTION_Wrigley Field                                       -0.000002
# APPLICATION_TYPE_C_EXPA                                                 -0.000001
# APPLICATION_TYPE_C_LOC                                                  -0.000002
# APPLICATION_TYPE_ISSUE                                                   0.000782
# APPLICATION_TYPE_RENEW                                                  -0.000778
#
#                                    LICENSE_DESCRIPTION_Residential Real Estate Developer  \
# criticalCount                                                           1.432951e-05
# seriousCount                                                           -9.349374e-05
# minorCount                                                             -4.533226e-04
# pastFail                                                               -1.911170e-05
# pastCritical                                                           -1.917995e-05
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -4.266004e-07
# APPLICATION_TYPE_C_EXPA                                                -3.412803e-07
# APPLICATION_TYPE_C_LOC                                                 -6.143046e-07
# APPLICATION_TYPE_ISSUE                                                 -3.320657e-05
# APPLICATION_TYPE_RENEW                                                  3.416216e-05
#
#                                    LICENSE_DESCRIPTION_Retail Food - Seasonal Lakefront Food Establishment  \
# criticalCount                                                           3.010903e-04
# seriousCount                                                            8.388670e-05
# minorCount                                                             -1.613445e-04
# pastFail                                                               -9.555849e-06
# pastCritical                                                           -9.589977e-06
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -2.133002e-07
# APPLICATION_TYPE_C_EXPA                                                -1.706402e-07
# APPLICATION_TYPE_C_LOC                                                 -3.071523e-07
# APPLICATION_TYPE_ISSUE                                                  1.140303e-04
# APPLICATION_TYPE_RENEW                                                 -1.135525e-04
#
#                                    LICENSE_DESCRIPTION_Retail Food Est.-Supplemental License for Dog-Friendly Areas  \
# criticalCount                                                          -1.274682e-05
# seriousCount                                                            4.194335e-05
# minorCount                                                             -1.133307e-04
# pastFail                                                               -4.777924e-06
# pastCritical                                                           -4.794988e-06
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -1.066501e-07
# APPLICATION_TYPE_C_EXPA                                                -8.532008e-08
# APPLICATION_TYPE_C_LOC                                                 -1.535761e-07
# APPLICATION_TYPE_ISSUE                                                 -8.301644e-06
# APPLICATION_TYPE_RENEW                                                  8.540540e-06
#
#                                    LICENSE_DESCRIPTION_Retail Food Establishment  \
# criticalCount                                                           0.005482
# seriousCount                                                            0.005309
# minorCount                                                              0.040107
# pastFail                                                                0.001923
# pastCritical                                                            0.003051
# ...                                                                          ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -0.001526
# APPLICATION_TYPE_C_EXPA                                                 0.000086
# APPLICATION_TYPE_C_LOC                                                 -0.000042
# APPLICATION_TYPE_ISSUE                                                  0.001803
# APPLICATION_TYPE_RENEW                                                 -0.001847
#
#                                    LICENSE_DESCRIPTION_Scavenger, Private  \
# criticalCount                                               -2.549364e-05
# seriousCount                                                -4.674687e-05
# minorCount                                                   2.958730e-04
# pastFail                                                    -9.555849e-06
# pastCritical                                                -9.589977e-06
# ...                                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                           -2.133002e-07
# APPLICATION_TYPE_C_EXPA                                     -1.706402e-07
# APPLICATION_TYPE_C_LOC                                      -3.071523e-07
# APPLICATION_TYPE_ISSUE                                       4.871350e-05
# APPLICATION_TYPE_RENEW                                      -4.823571e-05
#
#                                    LICENSE_DESCRIPTION_Shared Kitchen User  \
# criticalCount                                                 5.256997e-05
# seriousCount                                                  4.194335e-05
# minorCount                                                   -1.133307e-04
# pastFail                                                     -4.777924e-06
# pastCritical                                                 -4.794988e-06
# ...                                                                    ...
# LICENSE_DESCRIPTION_Wrigley Field                            -1.066501e-07
# APPLICATION_TYPE_C_EXPA                                      -8.532008e-08
# APPLICATION_TYPE_C_LOC                                       -1.535761e-07
# APPLICATION_TYPE_ISSUE                                        5.701514e-05
# APPLICATION_TYPE_RENEW                                       -5.677625e-05
#
#                                    LICENSE_DESCRIPTION_Special Event Food  \
# criticalCount                                                5.256997e-05
# seriousCount                                                 1.725769e-04
# minorCount                                                  -4.801387e-05
# pastFail                                                    -4.777924e-06
# pastCritical                                                -4.794988e-06
# ...                                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                           -1.066501e-07
# APPLICATION_TYPE_C_EXPA                                     -8.532008e-08
# APPLICATION_TYPE_C_LOC                                      -1.535761e-07
# APPLICATION_TYPE_ISSUE                                       5.701514e-05
# APPLICATION_TYPE_RENEW                                      -5.677625e-05
#
#                                    LICENSE_DESCRIPTION_Tavern  \
# criticalCount                                       -0.000070
# seriousCount                                         0.000372
# minorCount                                          -0.001836
# pastFail                                            -0.000059
# pastCritical                                        -0.000125
# ...                                                       ...
# LICENSE_DESCRIPTION_Wrigley Field                   -0.000003
# APPLICATION_TYPE_C_EXPA                             -0.000002
# APPLICATION_TYPE_C_LOC                              -0.000004
# APPLICATION_TYPE_ISSUE                              -0.000216
# APPLICATION_TYPE_RENEW                               0.000222
#
#                                    LICENSE_DESCRIPTION_Tire Facilty Class I (100 - 1,000 Tires)  \
# criticalCount                                                          -1.274682e-05
# seriousCount                                                           -2.337344e-05
# minorCount                                                              8.261970e-05
# pastFail                                                               -4.777924e-06
# pastCritical                                                           -4.794988e-06
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -1.066501e-07
# APPLICATION_TYPE_C_EXPA                                                -8.532008e-08
# APPLICATION_TYPE_C_LOC                                                 -1.535761e-07
# APPLICATION_TYPE_ISSUE                                                 -8.301644e-06
# APPLICATION_TYPE_RENEW                                                  8.540540e-06
#
#                                    LICENSE_DESCRIPTION_Tobacco  \
# criticalCount                                        -0.000370
# seriousCount                                         -0.000351
# minorCount                                           -0.000217
# pastFail                                             -0.000008
# pastCritical                                         -0.000139
# ...                                                        ...
# LICENSE_DESCRIPTION_Wrigley Field                    -0.000003
# APPLICATION_TYPE_C_EXPA                              -0.000002
# APPLICATION_TYPE_C_LOC                               -0.000004
# APPLICATION_TYPE_ISSUE                               -0.000241
# APPLICATION_TYPE_RENEW                                0.000248
#
#                                    LICENSE_DESCRIPTION_Wholesale Food Establishment  \
# criticalCount                                                              0.000072
# seriousCount                                                               0.000120
# minorCount                                                                -0.000960
# pastFail                                                                  -0.000030
# pastCritical                                                              -0.000096
# ...                                                                             ...
# LICENSE_DESCRIPTION_Wrigley Field                                         -0.000002
# APPLICATION_TYPE_C_EXPA                                                   -0.000002
# APPLICATION_TYPE_C_LOC                                                     0.000128
# APPLICATION_TYPE_ISSUE                                                    -0.000166
# APPLICATION_TYPE_RENEW                                                     0.000040
#
#                                    LICENSE_DESCRIPTION_Wrigley Field  \
# criticalCount                                               0.000400
# seriousCount                                               -0.000323
# minorCount                                                 -0.003617
# pastFail                                                   -0.000054
# pastCritical                                                0.000468
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                           0.001630
# APPLICATION_TYPE_C_EXPA                                    -0.000002
# APPLICATION_TYPE_C_LOC                                     -0.000004
# APPLICATION_TYPE_ISSUE                                      0.000054
# APPLICATION_TYPE_RENEW                                     -0.000048
#
#                                    APPLICATION_TYPE_C_EXPA  \
# criticalCount                                     0.000202
# seriousCount                                      0.000186
# minorCount                                        0.001391
# pastFail                                         -0.000096
# pastCritical                                     -0.000096
# ...                                                    ...
# LICENSE_DESCRIPTION_Wrigley Field                -0.000002
# APPLICATION_TYPE_C_EXPA                           0.001305
# APPLICATION_TYPE_C_LOC                           -0.000003
# APPLICATION_TYPE_ISSUE                           -0.000166
# APPLICATION_TYPE_RENEW                           -0.001136
#
#                                    APPLICATION_TYPE_C_LOC  \
# criticalCount                                   -0.000132
# seriousCount                                     0.000138
# minorCount                                      -0.000161
# pastFail                                        -0.000041
# pastCritical                                    -0.000173
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field               -0.000004
# APPLICATION_TYPE_C_EXPA                         -0.000003
# APPLICATION_TYPE_C_LOC                           0.002346
# APPLICATION_TYPE_ISSUE                          -0.000299
# APPLICATION_TYPE_RENEW                          -0.002044
#
#                                    APPLICATION_TYPE_ISSUE  \
# criticalCount                                    0.004653
# seriousCount                                     0.004352
# minorCount                                      -0.014859
# pastFail                                        -0.005444
# pastCritical                                    -0.006000
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                0.000054
# APPLICATION_TYPE_C_EXPA                         -0.000166
# APPLICATION_TYPE_C_LOC                          -0.000299
# APPLICATION_TYPE_ISSUE                           0.110951
# APPLICATION_TYPE_RENEW                          -0.110487
#
#                                    APPLICATION_TYPE_RENEW
# criticalCount                                   -0.004723
# seriousCount                                    -0.004676
# minorCount                                       0.013629
# pastFail                                         0.005581
# pastCritical                                     0.006268
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field               -0.000048
# APPLICATION_TYPE_C_EXPA                         -0.001136
# APPLICATION_TYPE_C_LOC                          -0.002044
# APPLICATION_TYPE_ISSUE                          -0.110487
# APPLICATION_TYPE_RENEW                           0.113666
#
# [2042 rows x 2042 columns]

# %%
X.corr(method='pearson', min_periods=1)
# Out:
#  -0.006168
# APPLICATION_TYPE_RENEW                                            0.006270
#
#                                    LICENSE_DESCRIPTION_Outdoor Patio  \
# criticalCount                                              -0.004013
# seriousCount                                                0.002389
# minorCount                                                  0.010015
# pastFail                                                    0.018737
# pastCritical                                               -0.002354
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                          -0.000462
# APPLICATION_TYPE_C_EXPA                                    -0.000413
# APPLICATION_TYPE_C_LOC                                     -0.000555
# APPLICATION_TYPE_ISSUE                                     -0.004361
# APPLICATION_TYPE_RENEW                                      0.004433
#
#                                    LICENSE_DESCRIPTION_Package Goods  \
# criticalCount                                              -0.003487
# seriousCount                                                0.032392
# minorCount                                                 -0.006516
# pastFail                                                    0.009921
# pastCritical                                               -0.002682
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                          -0.001499
# APPLICATION_TYPE_C_EXPA                                    -0.001340
# APPLICATION_TYPE_C_LOC                                     -0.001799
# APPLICATION_TYPE_ISSUE                                     -0.014141
# APPLICATION_TYPE_RENEW                                      0.014374
#
#                                    LICENSE_DESCRIPTION_Public Garage  \
# criticalCount                                              -0.005675
# seriousCount                                                0.009319
# minorCount                                                  0.000120
# pastFail                                                    0.026500
# pastCritical                                               -0.003329
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                          -0.000654
# APPLICATION_TYPE_C_EXPA                                    -0.000585
# APPLICATION_TYPE_C_LOC                                     -0.000785
# APPLICATION_TYPE_ISSUE                                     -0.006168
# APPLICATION_TYPE_RENEW                                      0.006270
#
#                                    LICENSE_DESCRIPTION_Public Place of Amusement  \
# criticalCount                                                          -0.004915
# seriousCount                                                           -0.007365
# minorCount                                                              0.004158
# pastFail                                                               -0.003933
# pastCritical                                                           -0.002883
# ...                                                                          ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -0.000566
# APPLICATION_TYPE_C_EXPA                                                -0.000506
# APPLICATION_TYPE_C_LOC                                                 -0.000680
# APPLICATION_TYPE_ISSUE                                                 -0.005342
# APPLICATION_TYPE_RENEW                                                  0.005430
#
#                                    LICENSE_DESCRIPTION_Regulated Business License  \
# criticalCount                                                            0.003191
# seriousCount                                                            -0.008100
# minorCount                                                              -0.018829
# pastFail                                                                -0.009086
# pastCritical                                                            -0.006661
# ...                                                                           ...
# LICENSE_DESCRIPTION_Wrigley Field                                       -0.001308
# APPLICATION_TYPE_C_EXPA                                                 -0.001170
# APPLICATION_TYPE_C_LOC                                                  -0.001570
# APPLICATION_TYPE_ISSUE                                                   0.072624
# APPLICATION_TYPE_RENEW                                                  -0.071400
#
#                                    LICENSE_DESCRIPTION_Residential Real Estate Developer  \
# criticalCount                                                               0.001595
# seriousCount                                                               -0.008504
# minorCount                                                                 -0.013925
# pastFail                                                                   -0.004541
# pastCritical                                                               -0.003329
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                          -0.000654
# APPLICATION_TYPE_C_EXPA                                                    -0.000585
# APPLICATION_TYPE_C_LOC                                                     -0.000785
# APPLICATION_TYPE_ISSUE                                                     -0.006168
# APPLICATION_TYPE_RENEW                                                      0.006270
#
#                                    LICENSE_DESCRIPTION_Retail Food - Seasonal Lakefront Food Establishment  \
# criticalCount                                                               0.047393
# seriousCount                                                                0.010790
# minorCount                                                                 -0.007009
# pastFail                                                                   -0.003211
# pastCritical                                                               -0.002354
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                          -0.000462
# APPLICATION_TYPE_C_EXPA                                                    -0.000413
# APPLICATION_TYPE_C_LOC                                                     -0.000555
# APPLICATION_TYPE_ISSUE                                                      0.029954
# APPLICATION_TYPE_RENEW                                                     -0.029470
#
#                                    LICENSE_DESCRIPTION_Retail Food Est.-Supplemental License for Dog-Friendly Areas  \
# criticalCount                                                              -0.002837
# seriousCount                                                                0.007630
# minorCount                                                                 -0.006962
# pastFail                                                                   -0.002270
# pastCritical                                                               -0.001664
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                          -0.000327
# APPLICATION_TYPE_C_EXPA                                                    -0.000292
# APPLICATION_TYPE_C_LOC                                                     -0.000392
# APPLICATION_TYPE_ISSUE                                                     -0.003084
# APPLICATION_TYPE_RENEW                                                      0.003135
#
#                                    LICENSE_DESCRIPTION_Retail Food Establishment  \
# criticalCount                                                           0.039841
# seriousCount                                                            0.031527
# minorCount                                                              0.080434
# pastFail                                                                0.029835
# pastCritical                                                            0.034571
# ...                                                                          ...
# LICENSE_DESCRIPTION_Wrigley Field                                      -0.152662
# APPLICATION_TYPE_C_EXPA                                                 0.009581
# APPLICATION_TYPE_C_LOC                                                 -0.003483
# APPLICATION_TYPE_ISSUE                                                  0.021868
# APPLICATION_TYPE_RENEW                                                 -0.022132
#
#                                    LICENSE_DESCRIPTION_Scavenger, Private  \
# criticalCount                                                   -0.004013
# seriousCount                                                    -0.006013
# minorCount                                                       0.012852
# pastFail                                                        -0.003211
# pastCritical                                                    -0.002354
# ...                                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                               -0.000462
# APPLICATION_TYPE_C_EXPA                                         -0.000413
# APPLICATION_TYPE_C_LOC                                          -0.000555
# APPLICATION_TYPE_ISSUE                                           0.012796
# APPLICATION_TYPE_RENEW                                          -0.012519
#
#                                    LICENSE_DESCRIPTION_Shared Kitchen User  \
# criticalCount                                                     0.011702
# seriousCount                                                      0.007630
# minorCount                                                       -0.006962
# pastFail                                                         -0.002270
# pastCritical                                                     -0.001664
# ...                                                                    ...
# LICENSE_DESCRIPTION_Wrigley Field                                -0.000327
# APPLICATION_TYPE_C_EXPA                                          -0.000292
# APPLICATION_TYPE_C_LOC                                           -0.000392
# APPLICATION_TYPE_ISSUE                                            0.021180
# APPLICATION_TYPE_RENEW                                           -0.020838
#
#                                    LICENSE_DESCRIPTION_Special Event Food  \
# criticalCount                                                    0.011702
# seriousCount                                                     0.031392
# minorCount                                                      -0.002949
# pastFail                                                        -0.002270
# pastCritical                                                    -0.001664
# ...                                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                               -0.000327
# APPLICATION_TYPE_C_EXPA                                         -0.000292
# APPLICATION_TYPE_C_LOC                                          -0.000392
# APPLICATION_TYPE_ISSUE                                           0.021180
# APPLICATION_TYPE_RENEW                                          -0.020838
#
#                                    LICENSE_DESCRIPTION_Tavern  \
# criticalCount                                       -0.003065
# seriousCount                                         0.013283
# minorCount                                          -0.022139
# pastFail                                            -0.005494
# pastCritical                                        -0.008494
# ...                                                       ...
# LICENSE_DESCRIPTION_Wrigley Field                   -0.001668
# APPLICATION_TYPE_C_EXPA                             -0.001492
# APPLICATION_TYPE_C_LOC                              -0.002002
# APPLICATION_TYPE_ISSUE                              -0.015738
# APPLICATION_TYPE_RENEW                               0.015996
#
#                                    LICENSE_DESCRIPTION_Tire Facilty Class I (100 - 1,000 Tires)  \
# criticalCount                                                              -0.002837
# seriousCount                                                               -0.004252
# minorCount                                                                  0.005075
# pastFail                                                                   -0.002270
# pastCritical                                                               -0.001664
# ...                                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                                          -0.000327
# APPLICATION_TYPE_C_EXPA                                                    -0.000292
# APPLICATION_TYPE_C_LOC                                                     -0.000392
# APPLICATION_TYPE_ISSUE                                                     -0.003084
# APPLICATION_TYPE_RENEW                                                      0.003135
#
#                                    LICENSE_DESCRIPTION_Tobacco  \
# criticalCount                                        -0.015294
# seriousCount                                         -0.011875
# minorCount                                           -0.002474
# pastFail                                             -0.000700
# pastCritical                                         -0.008971
# ...                                                        ...
# LICENSE_DESCRIPTION_Wrigley Field                    -0.001762
# APPLICATION_TYPE_C_EXPA                              -0.001575
# APPLICATION_TYPE_C_LOC                               -0.002115
# APPLICATION_TYPE_ISSUE                               -0.016622
# APPLICATION_TYPE_RENEW                                0.016895
#
#                                    LICENSE_DESCRIPTION_Wholesale Food Establishment  \
# criticalCount                                                              0.003568
# seriousCount                                                               0.004900
# minorCount                                                                -0.013199
# pastFail                                                                  -0.003215
# pastCritical                                                              -0.007448
# ...                                                                             ...
# LICENSE_DESCRIPTION_Wrigley Field                                         -0.001463
# APPLICATION_TYPE_C_EXPA                                                   -0.001308
# APPLICATION_TYPE_C_LOC                                                     0.072916
# APPLICATION_TYPE_ISSUE                                                    -0.013800
# APPLICATION_TYPE_RENEW                                                     0.003299
#
#                                    LICENSE_DESCRIPTION_Wrigley Field  \
# criticalCount                                               0.017813
# seriousCount                                               -0.011763
# minorCount                                                 -0.044474
# pastFail                                                   -0.005149
# pastCritical                                                0.032514
# ...                                                              ...
# LICENSE_DESCRIPTION_Wrigley Field                           1.000000
# APPLICATION_TYPE_C_EXPA                                    -0.001463
# APPLICATION_TYPE_C_LOC                                     -0.001963
# APPLICATION_TYPE_ISSUE                                      0.003995
# APPLICATION_TYPE_RENEW                                     -0.003508
#
#                                    APPLICATION_TYPE_C_EXPA  \
# criticalCount                                     0.010075
# seriousCount                                      0.007558
# minorCount                                        0.019120
# pastFail                                         -0.010160
# pastCritical                                     -0.007448
# ...                                                    ...
# LICENSE_DESCRIPTION_Wrigley Field                -0.001463
# APPLICATION_TYPE_C_EXPA                           1.000000
# APPLICATION_TYPE_C_LOC                           -0.001756
# APPLICATION_TYPE_ISSUE                           -0.013800
# APPLICATION_TYPE_RENEW                           -0.093248
#
#                                    APPLICATION_TYPE_C_LOC  \
# criticalCount                                   -0.004914
# seriousCount                                     0.004198
# minorCount                                      -0.001649
# pastFail                                        -0.003280
# pastCritical                                    -0.009998
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field               -0.001963
# APPLICATION_TYPE_C_EXPA                         -0.001756
# APPLICATION_TYPE_C_LOC                           1.000000
# APPLICATION_TYPE_ISSUE                          -0.018525
# APPLICATION_TYPE_RENEW                          -0.125170
#
#                                    APPLICATION_TYPE_ISSUE  \
# criticalCount                                    0.025127
# seriousCount                                     0.019207
# minorCount                                      -0.022146
# pastFail                                        -0.062768
# pastCritical                                    -0.050530
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field                0.003995
# APPLICATION_TYPE_C_EXPA                         -0.013800
# APPLICATION_TYPE_C_LOC                          -0.018525
# APPLICATION_TYPE_ISSUE                           1.000000
# APPLICATION_TYPE_RENEW                          -0.983847
#
#                                    APPLICATION_TYPE_RENEW
# criticalCount                                   -0.025199
# seriousCount                                    -0.020389
# minorCount                                       0.020068
# pastFail                                         0.063574
# pastCritical                                     0.052157
# ...                                                   ...
# LICENSE_DESCRIPTION_Wrigley Field               -0.003508
# APPLICATION_TYPE_C_EXPA                         -0.093248
# APPLICATION_TYPE_C_LOC                          -0.125170
# APPLICATION_TYPE_ISSUE                          -0.983847
# APPLICATION_TYPE_RENEW                           1.000000
#
# [2042 rows x 2042 columns]

# %%
cor_matrix = X.corr().abs()
upper_tri = cor_matrix.where(np.triu(np.ones(cor_matrix.shape),k=1).astype(np.bool))
to_drop = [column for column in upper_tri.columns if any(upper_tri[column] > 0.90)]
X.drop(to_drop, axis=1, inplace=True)

# %%
X.shape
# Out:
# (15311, 2031)

# %% [markdown]
# ## Data Splitting
#
# Here we split our data into train, validation, and test set. **(We might remove this section)**

# %%
#We might remove this section.
# Set seed
np.random.seed(10)

X_train, X_validate, y_train, y_validate = train_test_split(X, y, train_size = .80, test_size = .20)

# %% [markdown]
# ## Fit Models

# %% [markdown]
# Be sure to do the following:
#
# 1. Import the appropriate library from sklearn
# 2. Set up a hyperparameter grid (check out our previous labs to see how to do this)
# 3. Find the best hyperparameters, and then fit your model (using train/validation splits or cross-validation)

# %% [markdown]
# ### Model 1 - Support Vector Machine
# The first model we will utilize is a Support Vector Machine. SVM is a non-parametric method that looks for the "best separating hyperplane" between two classes.

# %%
# support vector machine

from sklearn.svm import SVC
from sklearn.model_selection import GridSearchCV
from sklearn import svm

# create SVM model
svm = SVC()

param_grid = {'C': [0.01, 0.1, 1], 
              'gamma': [0.001, 0.01, 0.1], 
              'kernel': ['rbf']}

svm_grid = GridSearchCV(SVC(), param_grid, cv=5, iid=False)
svm_grid.fit(X, y)
best_index = np.argmax(svm_grid.cv_results_["mean_test_score"])
best_svm_pred = svm_grid.best_estimator_.predict(X)

print(svm_grid.cv_results_["params"][best_index])
print('Validation Accuracy', accuracy_score(best_svm_pred, y.ravel()))


cv_scores = cross_val_score(svm_grid.best_estimator_, X, y, cv=5)
print(cv_scores)

# %% [markdown]
# ## Model 2

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier

features = X.to_numpy() #dataframe to matrix

cart = DecisionTreeClassifier() #classification regression tree
parameters = {'min_samples_leaf': [5],#@ least five samples to make a leaf. 
                'ccp_alpha': np.linspace(0, 0.1, 5)}
search_cv = GridSearchCV(cart, parameters, n_jobs=-1, cv=5, verbose=3).fit(features, y) # tell us which hyperparameters are the best performance
best_index = np.argmax(search_cv.cv_results_['mean_test_score'])
print('Best parameters: ', search_cv.cv_results_['params'][best_index])

cart = DecisionTreeClassifier(**search_cv.cv_results_['params'][best_index]).fit(features, y)

cv_scores = cross_val_score(cart, X, y, cv=5)
print(cv_scores)
# Out:
# Fitting 5 folds for each of 5 candidates, totalling 25 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  25 | elapsed:   24.1s remaining:    7.6s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:   26.7s finished
# Best parameters:  {'ccp_alpha': 0.025, 'min_samples_leaf': 5}
# [0.9222984  0.91541476 0.91312867 0.92913129 0.92945787]

# %%
# feature important
cart_data = pd.concat([pd.DataFrame(X.columns), pd.Series(cart.feature_importances_)], axis=1)
cart_data.columns = ['Feature', 'Importance']

sns.barplot(x="Importance", y="Feature", data=cart_data.nlargest(10, 'Importance')).set_title("Most Important CART Features")
plt.show()

# %% [markdown]
# ## Model 3

# %%
#Logistic Regression
# create a model
logit_reg = LogisticRegression(max_iter=1000)

param_grid = {'penalty': ['l1', 'l2', 'elasticnet'],
             'C': np.arange(.1, 1, .1),
               'fit_intercept': ['True', 'False'],
             'solver': ['liblinear', 'saga']}

logit_grid = GridSearchCV(logit_reg, param_grid, cv=5, iid=False)
logit_grid.fit(X, y)
best_index = np.argmax(logit_grid.cv_results_["mean_test_score"])
best_logit_pred = logit_grid.best_estimator_.predict(X)

print(logit_grid.cv_results_["params"][best_index])
print('Validation Accuracy', accuracy_score(best_logit_pred, y.ravel()))


cv_scores = cross_val_score(logit_grid.best_estimator_, X, y, cv=5)
print(cv_scores)
# Out:
# {'C': 0.1, 'fit_intercept': 'True', 'penalty': 'l1', 'solver': 'saga'}
# Validation Accuracy 0.9246293514466724
# [0.92262488 0.91606793 0.91410843 0.93043762 0.92815153]

# %%
#Confusion Matrix to Visualize the Predictions



cf_matrix = confusion_matrix(y, best_logit_pred, normalize = "true")

df_cm = pd.DataFrame(cf_matrix, range(2),
                  range(2))

df_cm = df_cm.rename(index=str, columns={0: "Pass", 1: "Fail"})
df_cm.index = ["Pass", "Fail"]
plt.figure(figsize = (10,7))
sns.set(font_scale=1.4)
sns.heatmap(df_cm, 
           annot=True,
           annot_kws={"size": 16},
           fmt='g')

plt.title("Confusion Matrix - Logistic Regression")
plt.xlabel("Predicted Label")
plt.ylabel("True Label")
plt.show()

# %% [markdown]
# ## Validation Metrics

# %% [markdown]
# **Hint**: Try writing a for loop to use [`cross_val_score()`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_score.html) to check for accuracy, precision, recall and f1 across all of your models.

# %% [markdown]
# ## Policy Simulation

# %% [markdown]
# ### Interpretable Machine Learning

# %% [markdown]
# **Hint**: Use tools like feature importance plots and coefficient plots

# %% [markdown]
# ### Coefficients with the largest absolute value:
# TBD

# %%
#Dataframe with the features and the logit coefficients 
logit_data = pd.concat([pd.DataFrame(X.columns),pd.DataFrame(np.transpose(logit_grid.best_estimator_.coef_))], axis = 1)
logit_data.columns = ['Feature', 'Coefficient']
logit_data['abs_coef'] = abs(logit_data['Coefficient'])

# %%
#Plotting the 10 coefficients with the largest absolute value
sns.barplot(x="Coefficient", y="Feature", data=logit_data.nlargest(10, 'abs_coef')).set_title("Top Logit Coefficients")
plt.show()

# %% [markdown]
# ## Prioritize Audits

# %% [markdown]
# **Hint**: Look up the [`.predict()`](https://www.kite.com/python/docs/sklearn.linear_model.SGDRegressor.predict), [`.predict_proba()`](https://www.kite.com/python/docs/sklearn.linear_model.LogisticRegression.predict_proba), and [`.sample()`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html) methods. Then:
# 1. Choose one of your models (or train a new simplified model or ensemble!) to predict outcomes and probabilities.
# 2. Order your audits by their probability of detecting a "Fail" score
# 3. Plot your distribution of pass/fail among the first 1000 observations in the dataset
# 4. Simulate random audits on the full chicago_2011_to_2013.csv dataset by picking 1000 observations at random

# %% [markdown]
# ### Predict on Data with Unseen Labels

# %%
# Fill in the code below with the X data you used for training
X_test = chicago_inspections_2014[chicago_inspections_2014.columns & ....columns]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-80875a464a31> in <module>
#       1 # Fill in the code below with the X data you used for training
# ----> 2 X_test = chicago_inspections_2014[chicago_inspections_2014.columns & ....columns]
#
# AttributeError: 'ellipsis' object has no attribute 'columns'
